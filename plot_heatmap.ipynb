# %%
curation = {
    # 'M15_2': {
    #     'M1': [], 
    #     'CA1': [1, 9, 10, 11, 12, 15, 16, 17, 18, 22, 25, 26, 27, 35, 40, 41, 42, 43, 44, 50, 51, 52, 53, 58, 60]
    # }, 
    # 'M15_3': {
    #     'M1': [1, 4, 7, 8, 9, 10, 11, 12, 13, 14, 16, 17, 19, 20, 21, 24, 25, 26, 27, 28, 32], 
    #     'CA1': [8, 17, 22, 27, 28]
    # }, 
    'M15_5': {
        # 'M1': [1, 21, 25, 26, 28, 30, 31, 32, 33], 
        # 'CA1': [1, 3, 5, 6, 7, 8, 9, 16, 30, 67, 71]
        # 'M1': (4.5, [25, 30, 31]), 
        'M1': (3.5, [28, 29, 31, 33, 35, 36, 37, 38, 39, 40, 41, 43, 44]), # use this 
        # 'CA1': (3.5, [3, 4, 5, 6, 7, 8, 9, 10, 11, 15, 21, 33, 62, 66, 68]),
        'CA1': (3.5, [8, 9, 10, 15, 21, 62]), # use this 
        # 'CA1': (4.5, [7, 8, 16, 30, 67, 71]), # 3, 5, 6, 69
    }, 
    'M15_7': {
        # 'M1': [7, 10, 11, 26, 27, 28, 32, 34, 35, 37, 38, 41, 43, 44, 45, 46, 50, 51, 53, 55, 56, 57, 59, 60, 61, 62, 64, 68, 69, 71, 72, 73, 74], 
        # 'M1': (3.5, [4, 6, 8, 9, 10, 11, 14, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 28, 29, 30, 31, 32, 35, 37, 38, 39, 41, 42, 44, 45, 46, 47, 48, 51, 52, 53, 54, 55, 56, 57, 58, 59, 62, 64, 65]),
        'M1': (3.5, [23, 24, 25, 29, 30, 32, 37, 41, 42, 44, 45, 46, 47, 51, 52, 53, 56, 57, 58, 59]),
        # 'CA1': [7, 8, 9, 10, 11, 12, 13, 14, 15, 22, 23]
    }, 
    # 'M16_1': {
    #     'M1': [], 
    #     'CA1': [1, 2, 4, 5, 6, 7, 8, 10, 17, 19, 20, 22, 24, 26, 27, 28, 29, 30, 31, 32, 33, 34, 37, 43, 44, 45, 47, 48, 49, 50, 51, 52, 53, 70, 72, 73, 85]
    # },
}
